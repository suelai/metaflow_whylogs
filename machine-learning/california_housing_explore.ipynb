# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing

# %%
dd = fetch_california_housing(as_frame=True)

# %%
dd
# Out:
# {'data':        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
#  0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
#  1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
#  2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
#  3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
#  4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#  ...       ...       ...       ...        ...         ...       ...       ...
#  20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
#  20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
#  20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
#  20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
#  20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#         Longitude
# ...

# %%
dd.frame.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

dd.frame.hist(figsize=(12, 10), bins=30, edgecolor="black")
plt.subplots_adjust(hspace=0.7, wspace=0.4)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(dd.data, dd.target, test_size=0.35 , random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.6092599367921091

# %%
lr.score(X_test,y_test)
# Out:
# 0.6079362417783192

# %%
dd.frame.sample(frac=0.5)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 4520   1.0333      18.0  3.651376   1.041284       547.0  2.509174     34.04
# 18915  1.7560      33.0  5.309322   1.008475       753.0  3.190678     38.15
# 14099  2.2287      29.0  3.707865   1.114607       882.0  1.982022     32.76
# 19295  3.7991      21.0  4.907407   1.006173       414.0  2.555556     38.37
# 7393   1.8672      43.0  5.050125   1.050125      1543.0  3.867168     33.96
# ...       ...       ...       ...        ...         ...       ...       ...
# 8092   3.6086      30.0  3.916084   1.093240      1779.0  4.146853     33.82
# 15512  5.0461      15.0  7.351981   1.137529      1656.0  3.860140     33.19
# 7841   2.4333      25.0  4.168293   1.078049      1177.0  2.870732     33.90
# 8898   2.9125      28.0  3.748159   1.107511      1548.0  2.279823     34.02
# 7911   3.5562      32.0  5.052778   1.072222      1679.0  4.663889     33.89
#
#        Longitude  MedHouseVal
# ...
